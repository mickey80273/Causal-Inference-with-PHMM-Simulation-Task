# %%
from phmm import PHMM

# %%
# Parameters
theta = [[0.5, 0.5],
            [0.5, 0.5]]
delta = [1.0, 0.0]
lambdas = [1.0, 5.4]
# Random parameters
theta_2 = [[0.3, 0.7],
            [0.7, 0.3]]
delta_2 = [1.0, 0.0]
lambdas_2 = [0.5, 6.7]
# Initialization
# Initialization
h_1 = PHMM(delta, theta, lambdas)
seqs, states = zip(*[h_1.gen_seq() for _ in range(20)])
# h_2 = PHMM(delta_2, theta_2, lambdas_2)
# h_2.baum_welch(seqs)
# print(h_2.transition_matrix())
# print(h_2.lambdas)
# v_2 = list(map(h_2.viterbi, seqs))
# print(list(zip(states[0], v_2[0])))
# print(h_2.log_likelihood(seqs))

# %%
col = [ i for i in range(100)]

# %%
seqs
# Out:
# ([1,
#   1,
#   1,
#   2,
#   2,
#   2,
#   0,
#   1,
#   1,
#   2,
#   6,
#   7,
#   8,
#   0,
#   3,
#   4,
#   0,
#   0,
#   1,
#   0,
#   3,
#   5,
#   0,
#   1,
#   3,
#   1,
#   2,
#   1,
#   0,
#   0,
#   1,
#   9,
#   6,
#   0,
#   1,
#   1,
#   1,
#   4,
#   3,
#   0,
#   0,
#   3,
#   2,
#   4,
#   2,
#   1,
#   1,
#   2,
#   0,
#   0,
#   3,
#   3,
#   8,
#   0,
#   1,
#   4,
#   2,
#   0,
#   1,
#   2,
#   5,
#   6,
#   3,
#   0,
#   0,
#   1,
#   5,
#   2,
#   6,
#   7,
#   4,
#   1,
#   9,
#   6,
#   9,
#   1,
#   1,
#   4,
#   4,
#   1,
#   0,
#   5,
#   5,
#   4,
#   2,
#   1,
#   1,
#   9,
#   2,
#   0,
#   8,
#   0,
#   4,
#   0,
#   4,
#   11,
#   1,
#   1,
#   0,
#   2],
#  [0,
#   7,
#   2,
#   0,
#   12,
#   0,
#   0,
#   6,
#   2,
#   1,
#   1,
#   0,
#   5,
#   0,
#   0,
#   2,
#   6,
#   1,
#   1,
#   1,
#   5,
#   9,
#   10,
#   6,
#   2,
#   1,
#   2,
#   0,
#   0,
#   6,
#   0,
#   6,
#   1,
#   5,
#   10,
#   4,
#   0,
#   4,
#   4,
#   5,
#   5,
#   4,
# ...

# %%
import pandas as pd
iii = pd.DataFrame(seqs)

# %%
iii = tuple(iii.values.tolist())

# %%
iii
# Out:
# ([1,
#   1,
#   1,
#   2,
#   2,
#   2,
#   0,
#   1,
#   1,
#   2,
#   6,
#   7,
#   8,
#   0,
#   3,
#   4,
#   0,
#   0,
#   1,
#   0,
#   3,
#   5,
#   0,
#   1,
#   3,
#   1,
#   2,
#   1,
#   0,
#   0,
#   1,
#   9,
#   6,
#   0,
#   1,
#   1,
#   1,
#   4,
#   3,
#   0,
#   0,
#   3,
#   2,
#   4,
#   2,
#   1,
#   1,
#   2,
#   0,
#   0,
#   3,
#   3,
#   8,
#   0,
#   1,
#   4,
#   2,
#   0,
#   1,
#   2,
#   5,
#   6,
#   3,
#   0,
#   0,
#   1,
#   5,
#   2,
#   6,
#   7,
#   4,
#   1,
#   9,
#   6,
#   9,
#   1,
#   1,
#   4,
#   4,
#   1,
#   0,
#   5,
#   5,
#   4,
#   2,
#   1,
#   1,
#   9,
#   2,
#   0,
#   8,
#   0,
#   4,
#   0,
#   4,
#   11,
#   1,
#   1,
#   0,
#   2],
#  [0,
#   7,
#   2,
#   0,
#   12,
#   0,
#   0,
#   6,
#   2,
#   1,
#   1,
#   0,
#   5,
#   0,
#   0,
#   2,
#   6,
#   1,
#   1,
#   1,
#   5,
#   9,
#   10,
#   6,
#   2,
#   1,
#   2,
#   0,
#   0,
#   6,
#   0,
#   6,
#   1,
#   5,
#   10,
#   4,
#   0,
#   4,
#   4,
#   5,
#   5,
#   4,
# ...

# %%
file_name = '/home/u56101022/Project/CartAnalysis/simulation/data/doc/dataset_12-13-2023_0statePHMM_parameters_12-13-2023_0.txt'

# Read the contents of the file
with open(file_name, 'r') as file:
    contents = file.read()

# %%
contents
# Out:
# 'Estimation of 2 state PHMM using monthly transaction data \n \nTransition Matrix: \n [[0.80255852 0.19744148]\n [0.59151831 0.40848169]] \nLambdas:\n [0.99341034 9.97237901] \nInitial Probability:\n [1. 0.] \n'

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("/home/u56101022/Project/CartAnalysis/simulation/data/final/simulation_data_0.csv")

print(np.mean(data["outcome"]))
print(np.std(data["outcome"]))
# Out:
# 176.903946050388
